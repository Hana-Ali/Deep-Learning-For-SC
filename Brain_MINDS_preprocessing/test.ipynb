# %%
import numpy as np
import matplotlib.pyplot as plt

path = "C:\\tractography\\connectome_injections\\A10-R01_0028-TT21_prob_connectivity.csv"

# Load the path
data = np.loadtxt(path, delimiter=',')
print(data.shape)
# Out:
# (139, 139)

# %%
# Plot the data
plt.imshow(data, cmap='jet')
