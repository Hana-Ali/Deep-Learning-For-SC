# %%
from utils import *
from models import *
from training import *

# %%
hpc = False
labs = False
paperspace = True

if hpc:
    main_data_path = "/rds/general/user/hsa22/ephemeral/Brain_MINDS/model_data_w_resize"
    main_logs_path = "/rds/general/user/hsa22/ephemeral/Brain_MINDS/tract_residuals"
elif labs:
    main_data_path = "/media/hsa22/Expansion/Brain_MINDS/model_data_w_resize"
    main_logs_path = "/media/hsa22/Expansion//Brain_MINDS/tract_residuals"
elif paperspace:
    main_data_path = "/notebooks/model_data_w_resize"
    main_logs_path = "/notebooks/tract_residuals"
else:
    main_data_path = "/media/hsa22/Expansion/Brain-MINDS/model_data_w_resize"
    main_logs_path = "media/hsa22/Expansion/Brain-MINDS/tract_residuals"

residual_arrays_path = os.path.join(main_logs_path, "predicted_residuals")
training_log_path = os.path.join(main_logs_path, "training_logs", "resnet_log.csv")
model_filename = os.path.join(main_logs_path, "models", "resnet_model.pt")

# %%
# Create the configs dictionary
configs = {

    ####### Model #######
    "model_name" : "resnet", # Model name
    "input_nc" : 1, # Number of input channels
    "output_nc" : 3, # Number of output channels
    "ngf" : 64, # Number of filters in first conv layer
    "num_blocks" : 3, # Number of residual blocks
    "norm_layer" : "BatchNorm3d", # Normalization layer
    "use_dropout" : False, # Dropout layers
    "padding_type" : "reflect", # Padding type
    
    ####### Training #######
    "n_epochs" : 10, # Number of epochs
    "loss" : "mse_loss", # Loss function
    "optimizer" : "Adam", # Optimizer
    "evaluation_metric" : "MSE_loss", # Evaluation metric
    "shuffle_dataset" : True,
    "separate_hemisphere" : True,
    "voxel_wise" : False,
    "wmfod_dwi" : "dwi",
    "save_best" : True, # Save best model
    "regularized" : False, # Regularization
    "vae" : False, # Variational autoencoder

    ####### Data #######
    "main_data_path" : main_data_path, # Data path
    "training_log_path" : training_log_path, # Training log path
    "model_filename" : model_filename, # Model filename
    "residual_arrays_path" : residual_arrays_path, # Path to the residuals array
    "batch_size" : 16, # Batch size
    "validation_batch_size" : 1, # Validation batch size
    
    ####### Parameters #######
    "initial_learning_rate" : 1e-04, # Initial learning rate
    "early_stopping_patience": 50, # Early stopping patience
    "decay_patience": 20, # Learning rate decay patience
    "decay_factor": 0.5, # Learning rate decay factor
    "min_learning_rate": 1e-08, # Minimum learning rate
    "save_last_n_models": 10, # Save last n models

    ####### Misc #######
    "skip_val" : True, # Skip validation

}

# %%
# Define the configuration path and save it as a .json file
config_path = os.path.join("configs", configs["model_name"] + ".json")

# Save the configuration
dump_json(configs, config_path)

# %%
# Load the configuration
configs = load_json(config_path)

# Define the metric to monitor based on whether we're skipping val or not
if configs["skip_val"]:
    metric_to_monitor = "train_loss"
else:
    metric_to_monitor = "val_loss"

# Define the groups
if configs["skip_val"]:
    groups = ("training",)
else:
    groups = ("training", "validation")

model_metrics = (configs["evaluation_metric"],)

run_pytorch_training(configs, configs["model_filename"], configs["training_log_path"],
                     configs["residual_arrays_path"],
                     metric_to_monitor=metric_to_monitor,
                     bias=None)
# Out:
# model name is:  resnet
# Model is: ResnetEncoder
# Metric to monitor is: train_loss
# injection_center_tiled shape is torch.Size([16, 3, 8, 8, 8])
# Number of elements in x_list: 8
# Number of elements in y_list: 22
# Number of elements in z_list: 14
# z is 3
# b0_cube shape is torch.Size([16, 1, 16, 16, 16])
# torch.Size([16, 1, 22, 22, 22])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 128, 16, 16, 16])
# torch.Size([16, 128, 16, 16, 16])
# torch.Size([16, 128, 16, 16, 16])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 32, 16, 16, 16])
# torch.Size([16, 32, 16, 16, 16])
# torch.Size([16, 32, 16, 16, 16])
# torch.Size([16, 3, 8, 8, 8])
# injection torch.Size([16, 3, 8, 8, 8])
# image torch.Size([16, 3, 8, 8, 8])
# concat torch.Size([16, 9, 8, 8, 8])
# joint shape torch.Size([16, 1, 8, 8, 8])
# z is 11
# b0_cube shape is torch.Size([16, 1, 16, 16, 16])
# torch.Size([16, 1, 22, 22, 22])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 128, 16, 16, 16])
# torch.Size([16, 128, 16, 16, 16])
# torch.Size([16, 128, 16, 16, 16])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 32, 16, 16, 16])
# torch.Size([16, 32, 16, 16, 16])
# torch.Size([16, 32, 16, 16, 16])
# torch.Size([16, 3, 8, 8, 8])
# injection torch.Size([16, 3, 8, 8, 8])
# image torch.Size([16, 3, 8, 8, 8])
# concat torch.Size([16, 9, 8, 8, 8])
# joint shape torch.Size([16, 1, 8, 8, 8])
# z is 19
# b0_cube shape is torch.Size([16, 1, 16, 16, 16])
# torch.Size([16, 1, 22, 22, 22])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 128, 16, 16, 16])
# torch.Size([16, 128, 16, 16, 16])
# torch.Size([16, 128, 16, 16, 16])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 32, 16, 16, 16])
# torch.Size([16, 32, 16, 16, 16])
# torch.Size([16, 32, 16, 16, 16])
# torch.Size([16, 3, 8, 8, 8])
# injection torch.Size([16, 3, 8, 8, 8])
# image torch.Size([16, 3, 8, 8, 8])
# concat torch.Size([16, 9, 8, 8, 8])
# joint shape torch.Size([16, 1, 8, 8, 8])
# z is 27
# b0_cube shape is torch.Size([16, 1, 16, 16, 16])
# torch.Size([16, 1, 22, 22, 22])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 128, 16, 16, 16])
# torch.Size([16, 128, 16, 16, 16])
# torch.Size([16, 128, 16, 16, 16])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 32, 16, 16, 16])
# torch.Size([16, 32, 16, 16, 16])
# torch.Size([16, 32, 16, 16, 16])
# torch.Size([16, 3, 8, 8, 8])
# injection torch.Size([16, 3, 8, 8, 8])
# image torch.Size([16, 3, 8, 8, 8])
# concat torch.Size([16, 9, 8, 8, 8])
# joint shape torch.Size([16, 1, 8, 8, 8])
# z is 35
# b0_cube shape is torch.Size([16, 1, 16, 16, 16])
# torch.Size([16, 1, 22, 22, 22])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 128, 16, 16, 16])
# torch.Size([16, 128, 16, 16, 16])
# torch.Size([16, 128, 16, 16, 16])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 32, 16, 16, 16])
# torch.Size([16, 32, 16, 16, 16])
# torch.Size([16, 32, 16, 16, 16])
# torch.Size([16, 3, 8, 8, 8])
# injection torch.Size([16, 3, 8, 8, 8])
# image torch.Size([16, 3, 8, 8, 8])
# concat torch.Size([16, 9, 8, 8, 8])
# joint shape torch.Size([16, 1, 8, 8, 8])
# z is 43
# b0_cube shape is torch.Size([16, 1, 16, 16, 16])
# torch.Size([16, 1, 22, 22, 22])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 128, 16, 16, 16])
# torch.Size([16, 128, 16, 16, 16])
# torch.Size([16, 128, 16, 16, 16])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 32, 16, 16, 16])
# torch.Size([16, 32, 16, 16, 16])
# torch.Size([16, 32, 16, 16, 16])
# torch.Size([16, 3, 8, 8, 8])
# injection torch.Size([16, 3, 8, 8, 8])
# image torch.Size([16, 3, 8, 8, 8])
# concat torch.Size([16, 9, 8, 8, 8])
# joint shape torch.Size([16, 1, 8, 8, 8])
# z is 51
# b0_cube shape is torch.Size([16, 1, 16, 16, 16])
# torch.Size([16, 1, 22, 22, 22])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 128, 16, 16, 16])
# torch.Size([16, 128, 16, 16, 16])
# torch.Size([16, 128, 16, 16, 16])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 32, 16, 16, 16])
# torch.Size([16, 32, 16, 16, 16])
# torch.Size([16, 32, 16, 16, 16])
# torch.Size([16, 3, 8, 8, 8])
# injection torch.Size([16, 3, 8, 8, 8])
# image torch.Size([16, 3, 8, 8, 8])
# concat torch.Size([16, 9, 8, 8, 8])
# joint shape torch.Size([16, 1, 8, 8, 8])
# z is 59
# b0_cube shape is torch.Size([16, 1, 16, 16, 16])
# torch.Size([16, 1, 22, 22, 22])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 128, 16, 16, 16])
# torch.Size([16, 128, 16, 16, 16])
# torch.Size([16, 128, 16, 16, 16])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 32, 16, 16, 16])
# torch.Size([16, 32, 16, 16, 16])
# torch.Size([16, 32, 16, 16, 16])
# torch.Size([16, 3, 8, 8, 8])
# injection torch.Size([16, 3, 8, 8, 8])
# image torch.Size([16, 3, 8, 8, 8])
# concat torch.Size([16, 9, 8, 8, 8])
# joint shape torch.Size([16, 1, 8, 8, 8])
# z is 67
# b0_cube shape is torch.Size([16, 1, 16, 16, 16])
# torch.Size([16, 1, 22, 22, 22])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 128, 16, 16, 16])
# torch.Size([16, 128, 16, 16, 16])
# torch.Size([16, 128, 16, 16, 16])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 32, 16, 16, 16])
# torch.Size([16, 32, 16, 16, 16])
# torch.Size([16, 32, 16, 16, 16])
# torch.Size([16, 3, 8, 8, 8])
# injection torch.Size([16, 3, 8, 8, 8])
# image torch.Size([16, 3, 8, 8, 8])
# concat torch.Size([16, 9, 8, 8, 8])
# joint shape torch.Size([16, 1, 8, 8, 8])
# z is 75
# b0_cube shape is torch.Size([16, 1, 16, 16, 16])
# torch.Size([16, 1, 22, 22, 22])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 128, 16, 16, 16])
# torch.Size([16, 128, 16, 16, 16])
# torch.Size([16, 128, 16, 16, 16])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 32, 16, 16, 16])
# torch.Size([16, 32, 16, 16, 16])
# torch.Size([16, 32, 16, 16, 16])
# torch.Size([16, 3, 8, 8, 8])
# injection torch.Size([16, 3, 8, 8, 8])
# image torch.Size([16, 3, 8, 8, 8])
# concat torch.Size([16, 9, 8, 8, 8])
# joint shape torch.Size([16, 1, 8, 8, 8])
# z is 83
# b0_cube shape is torch.Size([16, 1, 16, 16, 16])
# torch.Size([16, 1, 22, 22, 22])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 128, 16, 16, 16])
# torch.Size([16, 128, 16, 16, 16])
# torch.Size([16, 128, 16, 16, 16])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 32, 16, 16, 16])
# torch.Size([16, 32, 16, 16, 16])
# torch.Size([16, 32, 16, 16, 16])
# torch.Size([16, 3, 8, 8, 8])
# injection torch.Size([16, 3, 8, 8, 8])
# image torch.Size([16, 3, 8, 8, 8])
# concat torch.Size([16, 9, 8, 8, 8])
# joint shape torch.Size([16, 1, 8, 8, 8])
# z is 91
# b0_cube shape is torch.Size([16, 1, 16, 16, 16])
# torch.Size([16, 1, 22, 22, 22])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 256, 16, 16, 16])
# torch.Size([16, 128, 16, 16, 16])
# torch.Size([16, 128, 16, 16, 16])
# torch.Size([16, 128, 16, 16, 16])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 64, 16, 16, 16])
# torch.Size([16, 32, 16, 16, 16])
# torch.Size([16, 32, 16, 16, 16])
# torch.Size([16, 32, 16, 16, 16])
# torch.Size([16, 3, 8, 8, 8])
# injection torch.Size([16, 3, 8, 8, 8])
# image torch.Size([16, 3, 8, 8, 8])
# concat torch.Size([16, 9, 8, 8, 8])
# joint shape torch.Size([16, 1, 8, 8, 8])
# z is 99
# b0_cube shape is torch.Size([16, 1, 16, 16, 16])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [5], line 18
#      14     groups = ("training", "validation")
#      16 model_metrics = (configs["evaluation_metric"],)
# ---> 18 run_pytorch_training(configs, configs["model_filename"], configs["training_log_path"],
#      19                      configs["residual_arrays_path"],
#      20                      metric_to_monitor=metric_to_monitor,
#      21                      bias=None)
#
# File /notebooks/Marmoset_Residual_Training/training/pytorch_train.py:273, in run_pytorch_training(config, model_filename, training_log_filename, residual_arrays_path, verbose, use_multiprocessing, n_workers, model_name, n_gpus, regularized, test_input, metric_to_monitor, model_metrics, bias, pin_memory, amp, prefetch_factor, **unused_args)
#     269 metric_to_monitor = "train_loss"
#     272 # Train the model
# --> 273 train(model=model, optimizer=optimizer, criterion=criterion, n_epochs=config["n_epochs"], verbose=bool(verbose),
#     274     training_loader=train_loader, validation_loader=val_loader, test_loader=test_loader, model_filename=model_filename,
#     275     training_log_filename=training_log_filename, residual_arrays_path=residual_arrays_path,
#     276     separate_hemisphere=config["separate_hemisphere"], metric_to_monitor=metric_to_monitor,
#     277     early_stopping_patience=in_config("early_stopping_patience", config),
#     278     save_best=in_config("save_best", config, False),
#     279     learning_rate_decay_patience=in_config("decay_patience", config),
#     280     regularized=in_config("regularized", config, regularized),
#     281     n_gpus=n_gpus, voxel_wise=config["voxel_wise"],
#     282     vae=in_config("vae", config, False),
#     283     decay_factor=in_config("decay_factor", config),
#     284     min_lr=in_config("min_learning_rate", config),
#     285     learning_rate_decay_step_size=in_config("decay_step_size", config),
#     286     save_every_n_epochs=in_config("save_every_n_epochs", config),
#     287     save_last_n_models=in_config("save_last_n_models", config),
#     288     amp=False)
#
# File /notebooks/Marmoset_Residual_Training/training/pytorch_train.py:75, in train(model, optimizer, criterion, n_epochs, training_loader, validation_loader, test_loader, training_log_filename, model_filename, residual_arrays_path, separate_hemisphere, voxel_wise, metric_to_monitor, early_stopping_patience, learning_rate_decay_patience, save_best, n_gpus, verbose, regularized, vae, decay_factor, min_lr, learning_rate_decay_step_size, save_every_n_epochs, save_last_n_models, amp)
#      72     break
#      74 # Train the model
# ---> 75 loss = epoch_training(training_loader, model, criterion, optimizer=optimizer, epoch=epoch, voxel_wise=voxel_wise,
#      76                       residual_arrays_path=residual_arrays_path, separate_hemisphere=separate_hemisphere,
#      77                       n_gpus=n_gpus, regularized=regularized, vae=vae, scaler=scaler)
#      79 try:
#      80     training_loader.dataset.on_epoch_end()
#
# File /notebooks/Marmoset_Residual_Training/utils/training_utils/training_funcs.py:117, in epoch_training(train_loader, model, criterion, optimizer, epoch, residual_arrays_path, separate_hemisphere, n_gpus, print_frequency, voxel_wise, distributed, regularized, print_gpu_memory, vae, scaler)
#     114 print("b0_cube shape is", b0_cube.shape)
#     116 # Get the model output
# --> 117 (predicted_residual, loss, batch_size)  = batch_loss(model, b0_cube, injection_center_tiled, image_coordinates,
#     118                                                      current_residual, criterion, distributed=distributed,
#     119                                                      n_gpus=n_gpus, use_amp=use_amp)
#     121 # Get the residual as a numpy array
#     122 predicted_residual = predicted_residual.cpu().detach().numpy()
#
# File /notebooks/Marmoset_Residual_Training/utils/training_utils/training_funcs.py:210, in batch_loss(model, b0_cube, injection_center, image_coordinates, residual_cube, criterion, distributed, n_gpus, use_amp)
#     206 # If not running serially, put the data on the GPU
#     207 if not distributed:
#     208
#     209     # Empty cache
# --> 210     torch.cuda.empty_cache()
#     212     # Get all the data on the GPU
#     213     b0_cube = b0_cube.cuda()
#
# File /usr/local/lib/python3.9/dist-packages/torch/cuda/memory.py:121, in empty_cache()
#     110 r"""Releases all unoccupied cached memory currently held by the caching
#     111 allocator so that those can be used in other GPU application and visible in
#     112 `nvidia-smi`.
#    (...)
#     118     more details about GPU memory management.
#     119 """
#     120 if is_initialized():
# --> 121     torch._C._cuda_emptyCache()
#
# KeyboardInterrupt:
